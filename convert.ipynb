# %%
import os

# %%
import pandas as pd

# %%
df = pd.read_csv('./Output/dataset.csv')

# %%
df
# Out:
#     category1_original_1050.png_fa4719f4-9e3e-471e-9f48-78883c06d237.png  \
# 0    category1_original_1024.png_e29b84ea-7f9b-4b8e...
# 1    category1_original_1023.png_5c970e3a-708c-4ed7...
# 2    category1_original_1021.png_de3f04ad-4e82-4da1...
# 3    category1_original_1030.png_eba574e1-82e5-4ec1...
# 4    category1_original_1041.png_3a4303ef-8d9d-4052...
# 5    category1_original_1031.png_7973318b-bdce-4cef...
# 6    category1_original_1000.png_c89211f0-607b-4454...
# 7                                            .DS_Store
# 8    category1_original_1025.png_194aabbf-d34c-406c...
# 9    category1_original_1050.png_47749bc0-6e2b-43c9...
# 10   category1_original_1011.png_4172b2d5-adde-4f10...
# 11   category1_original_1031.png_257d396c-0ea1-4e7f...
# 12   category1_original_1050.png_5f5015cf-b6c4-492e...
# 13   category1_original_1032.png_0566d1d1-03c4-451b...
# 14   category1_original_1030.png_c6ea81e9-d184-4be6...
# 15   category1_original_1042.png_fd8fb574-ef2d-47b4...
# ...

# %%
x = df.iloc[:].values

# %%
import json

# %%
x = x.tolist()

# %%
fp = open('Output/dataset.json', 'w')
json.dump(x, fp)

# %%
df1 = pd.read_csv('./Output/results1.csv')

# %%
df1
# Out:
#    Test_original_6053.png_62171105-bdaa-4eb5-b5e7-9b0fb7914715.png  1
# 0   Test_original_4052.png_31cd9a66-9edc-4445-b4bc...               2
# 1   Test_original_1052.png_22a82512-5b1f-4072-a4af...               0
# 2                                            1051.png               0
# 3   Test_original_4052.png_a2ba34f8-9e8b-4b2d-ad89...               2
# 4   Test_original_6052.png_9950e35a-38c7-4388-b391...               1
# 5                                            1052.png               0
# 6   Test_original_C052.png_5c226e55-09ba-4fd0-bf6b...               3
# 7                                            C052.png               3
# 8                                            4043.png               2
# 9                                            C053.png               3
# 10  Test_original_6052.png_25bb57e2-b542-47c3-9abb...               1
# 11                                           6052.png               1
# ...

# %%
x1 = df1.iloc[:].values

# %%
x1 = x1.tolist()

# %%
fp1 = open('Output/results1.json', 'w')
json.dump(x1, fp1)

# %%
x1
# Out:
# [['Test_original_4052.png_31cd9a66-9edc-4445-b4bc-9b0239b342e0.png', 2],
#  ['Test_original_1052.png_22a82512-5b1f-4072-a4af-9a8af40653f0.png', 0],
#  ['1051.png', 0],
#  ['Test_original_4052.png_a2ba34f8-9e8b-4b2d-ad89-612c261a9654.png', 2],
#  ['Test_original_6052.png_9950e35a-38c7-4388-b391-ce50bb8ea1a7.png', 1],
#  ['1052.png', 0],
#  ['Test_original_C052.png_5c226e55-09ba-4fd0-bf6b-e0d2b411baa3.png', 3],
#  ['C052.png', 3],
#  ['4043.png', 2],
#  ['C053.png', 3],
#  ['Test_original_6052.png_25bb57e2-b542-47c3-9abb-a1f7c7179ee6.png', 1],
#  ['6052.png', 1],
#  ['4051.png', 2],
#  ['Test_original_1052.png_b95bc311-bae0-48a7-8b9f-d0eddf1ddf2b.png', 0],
#  ['6053.png', 1],
#  ['Test_original_1051.png_271f7fb1-f0ab-4ca7-9dae-a352fd0ed8b9.png', 0],
#  ['4050.png', 2],
#  ['Test_original_4052.png_209d62b3-92ce-4e4d-8006-cf63a40088a4.png', 2],
#  ['Test_original_4052.png_78b7cca7-2a16-4f3c-829d-e4937b5f2dc2.png', 2],
# ...
